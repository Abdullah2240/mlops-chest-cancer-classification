# %%
d = {"key":"value", "key1":"value1"}

# %%
d["key"]
# Out:
# 'value'

# %%
from box import ConfigBox
d2 = {"key":"value", "key1":"value1"}
d2 = ConfigBox(d2)

# %%
d2.key1
# Out:
# 'value1'

# %%
from ensure import ensure_annotations
@ensure_annotations
def get_product(x:int, y:int):
    return x*y

get_product(4, 5)
# Out:
# 20

# %%
get_product(x=2, y="4")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 get_product(x=2, y="4")
#
# File c:\Users\Hp\miniconda3\envs\cancer\lib\site-packages\ensure\main.py:833, in WrappedFunction.__call__(self, *args, **kwargs)
#     831     if not isinstance(value, templ):
#     832         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 833         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     835 return self.f(*args, **kwargs)
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x00000214F7478790> does not match annotation type <class 'int'>

# %% [markdown]
# ### Download data from G drive

# %%
import gdown

# %%
url = "fea/fefef/effeeffe/lamburghuini/view?" # Public link to dataset

# %%
file_id = url.split("/")[-2]
prefix = "https://drive.google.com/uc?/export=download&id="
path = prefix + file_id
gdown.download(path, "Chest-CT-Scan-data.zip")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 file_id = url.split("/")[-2]
#       2 prefix = "https://drive.google.com/uc?/export=download&id="
#       3 path = prefix + file_id
#
# NameError: name 'url' is not defined

# %%
# %pwd
# Out:
# 'c:\\Users\\Hp\\Code\\mlops-chest-cancer-classification\\research'

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 4230-F99E
#
#  Directory of c:\Users\Hp\Code\mlops-chest-cancer-classification\artifacts\data_ingestion\Data
#
# 02/01/2026  12:38 PM    <DIR>          .
# 02/01/2026  12:38 PM    <DIR>          ..
# 02/01/2026  12:38 PM    <DIR>          test
# 02/01/2026  12:38 PM    <DIR>          train
# 02/01/2026  12:38 PM    <DIR>          valid
#                0 File(s)              0 bytes
#                5 Dir(s)  242,552,848,384 bytes free

# %%
# %ls train
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 4230-F99E
#
#  Directory of c:\Users\Hp\Code\mlops-chest-cancer-classification\artifacts\data_ingestion\Data\train
#
# 02/01/2026  12:38 PM    <DIR>          .
# 02/01/2026  12:38 PM    <DIR>          ..
# 02/01/2026  12:38 PM    <DIR>          adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib
# 02/01/2026  12:38 PM    <DIR>          large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa
# 02/01/2026  12:38 PM    <DIR>          normal
# 02/01/2026  12:38 PM    <DIR>          squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa
#                0 File(s)              0 bytes
#                6 Dir(s)  242,567,028,736 bytes free

# %%
# %ls test
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 4230-F99E
#
#  Directory of c:\Users\Hp\Code\mlops-chest-cancer-classification\artifacts\data_ingestion\Data\test
#
# 02/01/2026  12:38 PM    <DIR>          .
# 02/01/2026  12:38 PM    <DIR>          ..
# 02/01/2026  12:38 PM    <DIR>          adenocarcinoma
# 02/01/2026  12:38 PM    <DIR>          large.cell.carcinoma
# 02/01/2026  12:38 PM    <DIR>          normal
# 02/01/2026  12:38 PM    <DIR>          squamous.cell.carcinoma
#                0 File(s)              0 bytes
#                6 Dir(s)  242,567,389,184 bytes free

# %%
# %ls valid
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 4230-F99E
#
#  Directory of c:\Users\Hp\Code\mlops-chest-cancer-classification\artifacts\data_ingestion\Data\valid
#
# 02/01/2026  12:38 PM    <DIR>          .
# 02/01/2026  12:38 PM    <DIR>          ..
# 02/01/2026  12:38 PM    <DIR>          adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib
# 02/01/2026  12:38 PM    <DIR>          large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa
# 02/01/2026  12:38 PM    <DIR>          normal
# 02/01/2026  12:38 PM    <DIR>          squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa
#                0 File(s)              0 bytes
#                6 Dir(s)  242,567,454,720 bytes free
